# %% [markdown]
# Data is comming from the archive http://www.laurent-duval.eu/opus-dual-spls-sparse-pls/Data-dual-sPLS-NIR-near-infrared-spectra-density/matrixXYNir-CSV-dual-sparse-pls.7z (see **Dataset of near-infrared (NIR) spectral data for prediction of organic matter and total carbon in agricultural soil using homemade NIR spectrometer**). Like the paper said, X matrix is tranformed using the Savitzky–Golay filter before use. Here we introduce Dual-sPLS performance using *RMSE* metric for different norms on real data (NIR dataset). Norms $\Omega$ includes :
#
# * Lasso (*lasso.py*)
# * Ridge (*ridge.py*)
# * GLA (*GLA.py*)
# * GLB (*GLB.py*)
# * GLC (*GLC.py*)
# * $\mathcal{l}_2$ norm (*LS.py*)

# %%
# Importing libraries
import numpy as np
import pandas as pd
import sys
from pathlib import Path
import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics         import mean_squared_error
from sklearn.cluster         import AgglomerativeClustering

# Dual-sPLS library - norms
from dual_spls.lasso import dual_spls_lasso
from dual_spls.ridge import d_spls_ridge
from dual_spls.GLA   import dual_spls_gla_random
from dual_spls.GLB   import dual_spls_glb
from dual_spls.GLC   import dual_spls_glc
from dual_spls.LS    import d_spls_ls

sns.set_style("darkgrid")

# %%
# Import dataset
X = pd.read_csv(
    "../data/matrixXNirSpectrumDerivative.csv"
)
X.head()
# Out:
#    0.00293123424053193  0.00255436311875071  0.0020018325320312  \
# 0             0.002981             0.002625            0.002059
# 1             0.003050             0.002717            0.002144
# 2             0.003139             0.002831            0.002253
# 3             0.003246             0.002962            0.002377
# 4             0.003365             0.003105            0.002510
#
#    0.00196149115051542  0.00192856660911015  0.0026838980615139  \
# 0             0.002022             0.001990            0.002611
# 1             0.002109             0.002077            0.002578
# 2             0.002213             0.002184            0.002584
# 3             0.002333             0.002307            0.002632
# 4             0.002468             0.002444            0.002715
#
#    0.00185868952955519  0.00212735352771622  0.00210245932851519  \
# 0             0.001919             0.002184             0.002161
# 1             0.002006             0.002266             0.002243
# 2             0.002115             0.002367             0.002342
# 3             0.002241             0.002483             0.002455
# 4             0.002380             0.002614             0.002584
#
#    0.00222007227795464  ...  0.00218016813908305  0.00187072977423667  \
# 0             0.002267  ...             0.002229             0.001931
# 1             0.002340  ...             0.002302             0.002017
# 2             0.002433  ...             0.002399             0.002127
# 3             0.002542  ...             0.002510             0.002253
# 4             0.002666  ...             0.002634             0.002391
#
#    0.00272921706948961  0.00301864594221115  0.00199910349079539  \
# 0             0.002490             0.002956             0.002058
# 1             0.002316             0.002925             0.002146
# 2             0.002213             0.002929             0.002257
# 3             0.002180             0.002969             0.002383
# 4             0.002209             0.003042             0.002518
#
#    0.00191627740859985  0.00268596070153373  0.00232852495142393  \
# 0             0.001977             0.002400             0.002340
# 1             0.002065             0.002189             0.002380
# 2             0.002174             0.002058             0.002448
# 3             0.002299             0.002007             0.002540
# 4             0.002436             0.002026             0.002651
#
#    0.00253164342471531  0.00188808962702751
# 0             0.002562             0.001951
# 1             0.002616             0.002038
# 2             0.002693             0.002147
# 3             0.002795             0.002272
# 4             0.002918             0.002409
#
# [5 rows x 208 columns]

# %%
y = pd.read_csv("../data/matrixYNirPropertyDensityNormalized.csv", header=None)
y.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.536704  0.616918  0.848809  0.894507  0.899854  0.268838  0.906174
#
#         7         8         9    ...       198      199       200       201  \
# 0  0.794361  0.854157  0.755955  ...  0.782207  0.90666  0.129315  0.337385
#
#         202      203       204       205       206       207
# 0  0.870685  0.90034  0.085561  0.506077  0.609626  0.913952
#
# [1 rows x 208 columns]

# %%
# Initialization

def cv_rmse(model_fun, X, y, **kwargs):
    rmses = []

    for train_idx, test_idx in kf.split(X):
        Xtr, Xte = X[train_idx], X[test_idx]
        ytr, yte = y[train_idx], y[test_idx]

        try:
            model = model_fun(Xtr, ytr, n_components=n_comp, **kwargs)

            y_pred = (
                (Xte - model["Xmean"])
                @ model["Bhat"][:, -1]
                + model["intercept"][-1]
            )

            # For divergent models
            if not np.all(np.isfinite(y_pred)):
                return np.inf, None

            rmse = np.sqrt(mean_squared_error(yte, y_pred))
            rmses.append(rmse)

        except Exception:
            return np.inf, None

    return np.mean(rmses), model

# ----------- Init for grid search and K fold (K=5) ----------- #
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_score = np.inf
best_models = {}
best_params = {}

# ----------- Data (adapted to the lib) ----------- #
X = pd.read_csv(
    "../data/matrixXNirSpectrumDerivative.csv",
     header=None
).T.values
y = pd.read_csv(
    "../data/matrixYNirPropertyDensityNormalized.csv",
    header=None
).values.ravel()

# ----------- Params ----------- #

n_comp = 6
labels = AgglomerativeClustering(n_clusters=25).fit(X.T).labels_  # for GL*
indG = labels + 1  # 1-based groups vector

# Sparsity params
nG = indG.max()    # groups number. same for all GL*

ppnu_grid = np.linspace(0.01, 1, 10)
nu2_grid = np.logspace(-3, 1, 7)         # For Ridge
gamma_grid = np.linspace(0.01, 1.0, 10)  # For GLC

# %%
# Hyperparameter tunning using grid search and 5 fold cross - validation

####################
#### LASSO #########
####################

best_rmse = np.inf

for ppnu in ppnu_grid:

    print(f"------------- Grid search - ppnu = {ppnu} -------------")
    rmse, model = cv_rmse(
        dual_spls_lasso, X, y, ppnu=ppnu
    )
    if rmse < best_rmse:
        best_rmse = rmse
        best_models["Lasso"] = {
            "model": model,
            "rmse": rmse,
            "params": {"ppnu": ppnu}
        }

####################
#### RIDGE #########
####################

best_rmse = np.inf

for ppnu in ppnu_grid:
    for nu2 in nu2_grid:

        print(f"------------- Grid search - ppnu = {ppnu}, nu = {nu2} -------------")
        
        rmse, model = cv_rmse(
            d_spls_ridge,
            X, y,
            ppnu=ppnu,
            nu2=nu2
        )

        if rmse < best_rmse:
            best_rmse = rmse
            best_models["Ridge"] = {
                "model": model,
                "rmse": rmse,
                "params": {
                    "ppnu": ppnu,
                    "nu2": nu2
                }
            }

            
####################
#### LS (L2) #######
####################

best_rmse = np.inf

for ppnu in ppnu_grid:

    print(f"------------- Grid search - ppnu = {ppnu} -------------")
    rmse, model = cv_rmse(
        d_spls_ls, X, y, ppnu=ppnu
    )
    if rmse < best_rmse:
        best_rmse = rmse
        best_models["LS"] = {
            "model": model,
            "rmse": rmse,
            "params": {"ppnu": ppnu}
        }

####################
#### GLA ###########
####################

best_rmse = np.inf

for ppnu in ppnu_grid:

    print(f"------------- Grid search - ppnu = {ppnu} -------------")
    rmse, model = cv_rmse(
        dual_spls_gla_random,
        X, y,
        ppnu=np.repeat(ppnu, nG),
        indG=indG,
        verbose=False
    )
    if rmse < best_rmse:
        best_rmse = rmse
        best_models["GLA"] = {
            "model": model,
            "rmse": rmse,
            "params": {"ppnu": ppnu}
        }

####################
#### GLB ###########
####################

best_rmse = np.inf

for ppnu in ppnu_grid:

    print(f"------------- Grid search - ppnu = {ppnu} -------------")
    rmse, model = cv_rmse(
        dual_spls_glb,
        X, y,
        ppnu=np.repeat(ppnu, nG),
        indG=indG,
        verbose=False
    )
    if rmse < best_rmse:
        best_rmse = rmse
        best_models["GLB"] = {
            "model": model,
            "rmse": rmse,
            "params": {"ppnu": ppnu}
        }

####################
#### GLC ###########
####################

best_rmse = np.inf

for ppnu in ppnu_grid:
    for gamma in gamma_grid:

        print(f"------------- Grid search - ppnu = {ppnu}, gamma = {gamma} -------------")
        gamma_vec = np.repeat(gamma, nG)
        gamma_vec /= gamma_vec.sum()

        rmse, model = cv_rmse(
            dual_spls_glc,
            X, y,
            ppnu=np.repeat(ppnu, nG),
            indG=indG,
            gamma=gamma_vec,
            verbose=False
        )

        if rmse < best_rmse:
            best_rmse = rmse
            best_models["GLC"] = {
                "model": model,
                "rmse": rmse,
                "params": {"ppnu": ppnu, "gamma": gamma}
            }
# Out:
# Dual PLS Lasso ic=1 lambda1=0.0002 mu=1.0077 nu=0.00021867345372693941 nbzeros=26
# Dual PLS Lasso ic=2 lambda1=0.0002 mu=0.1279 nu=2.3448982716472975e-05 nbzeros=0
# Dual PLS Lasso ic=3 lambda1=0.0010 mu=0.0265 nu=2.737214050172478e-05 nbzeros=0
# Dual PLS Lasso ic=4 lambda1=0.0001 mu=0.0122 nu=1.8262111702803436e-06 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0002 mu=0.0078 nu=1.3763423001534436e-06 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0004 mu=0.0031 nu=1.3224989575516115e-06 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0002 mu=1.0840 nu=0.00020761260248566967 nbzeros=26
# Dual PLS Lasso ic=2 lambda1=0.0004 mu=0.1290 nu=5.7516029554300084e-05 nbzeros=0
# Dual PLS Lasso ic=3 lambda1=0.0012 mu=0.0289 nu=3.478079851976668e-05 nbzeros=0
# Dual PLS Lasso ic=4 lambda1=0.0001 mu=0.0115 nu=1.6110593790907594e-06 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0002 mu=0.0075 nu=1.2789495547888654e-06 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0002 mu=0.0038 nu=8.694209682144232e-07 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0002 mu=1.0697 nu=0.00018657596869052127 nbzeros=26
# Dual PLS Lasso ic=2 lambda1=0.0004 mu=0.1270 nu=5.329717391193125e-05 nbzeros=0
# Dual PLS Lasso ic=3 lambda1=0.0009 mu=0.0215 nu=1.8624834422676906e-05 nbzeros=0
# Dual PLS Lasso ic=4 lambda1=0.0002 mu=0.0098 nu=1.676409598954915e-06 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0002 mu=0.0075 nu=1.591330593450799e-06 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0003 mu=0.0032 nu=9.79745072419436e-07 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0002 mu=1.1025 nu=0.0001889392827767652 nbzeros=26
# Dual PLS Lasso ic=2 lambda1=0.0005 mu=0.1277 nu=5.782593633259933e-05 nbzeros=0
# Dual PLS Lasso ic=3 lambda1=0.0011 mu=0.0234 nu=2.5633371897187355e-05 nbzeros=0
# Dual PLS Lasso ic=4 lambda1=0.0001 mu=0.0099 nu=1.346102559821562e-06 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0003 mu=0.0088 nu=2.4208211665279684e-06 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.
-06 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0017 mu=1.0630 nu=0.0018155582132524078 nbzeros=364
# Dual PLS Lasso ic=2 lambda1=0.0043 mu=0.1124 nu=0.0004862554064104275 nbzeros=197
# Dual PLS Lasso ic=3 lambda1=0.0100 mu=0.0197 nu=0.0001970976539205648 nbzeros=29
# Dual PLS Lasso ic=4 lambda1=0.0021 mu=0.0098 nu=2.0617963307793562e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0047 mu=0.0077 nu=3.607642430683468e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0035 mu=0.0029 nu=1.009865444920761e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0020 mu=0.9695 nu=0.001905727240906875 nbzeros=389
# Dual PLS Lasso ic=2 lambda1=0.0043 mu=0.1164 nu=0.0004955588116378884 nbzeros=215
# Dual PLS Lasso ic=3 lambda1=0.0118 mu=0.0191 nu=0.00022614995555069622 nbzeros=30
# Dual PLS Lasso ic=4 lambda1=0.0026 mu=0.0101 nu=2.623840816106293e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0050 mu=0.0078 nu=3.937848385850401e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0035 mu=0.0026 nu=9.095708079883362e-06 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0020 mu=1.0425 nu=0.0020831650948717998 nbzeros=389
# Dual PLS Lasso ic=2 lambda1=0.0048 mu=0.1170 nu=0.0005570765206780895 nbzeros=217
# Dual PLS Lasso ic=3 lambda1=0.0102 mu=0.0215 nu=0.00021992844582171793 nbzeros=42
# Dual PLS Lasso ic=4 lambda1=0.0022 mu=0.0102 nu=2.2539004677183935e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0037 mu=0.0074 nu=2.7860720075743144e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0038 mu=0.0032 nu=1.1938119283316622e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0018 mu=1.0347 nu=0.0018681455842266927 nbzeros=389
# Dual PLS Lasso ic=2 lambda1=0.0057 mu=0.1101 nu=0.0006310083793810939 nbzeros=205
# Dual PLS Lasso ic=3 lambda1=0.0084 mu=0.0167 nu=0.0001398281689004573 nbzeros=57
# Dual PLS Lasso ic=4 lambda1=0.0024 mu=0.0076 nu=1.8302911941295782e-05 nbzeros=1
# Dual PLS Lasso ic=5 lambda1=0.0048 mu=0.0078 nu=3.7399021034912445e-05 nbzeros=1
# Dual PLS Lasso ic=6 lambda1=0.0040 mu=0.0026 nu=1.0441514346941339e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0017 mu=1.0691 nu=0.0017707957378109676 nbzeros=389
# Dual PLS Lasso ic=2 lambda1=0.0042 mu=0.1160 nu=0.000490648250170534 nbzeros=219
# Dual PLS Lasso ic=3 lambda1=0.0091 mu=0.0180 nu=0.00016348508802458076 nbzeros=53
# Dual PLS Lasso ic=4 lambda1=0.0026 mu=0.0081 nu=2.1118135247371445e-05 nbzeros=1
# Dual PLS Lasso ic=5 lambda1=0.0053 mu=0.0088 nu=4.7027444755374845e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0033 mu=0.0021 nu=6.888507066198761e-06 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0018 mu=1.0604 nu=0.0019451877756463442 nbzeros=389
# Dual PLS Lasso ic=2 lambda1=0.0045 mu=0.1123 nu=0.0005004193544934232 nbzeros=215
# Dual PLS Lasso ic=3 lambda1=0.0102 mu=0.0196 nu=0.00019971606245295135 nbzeros=43
# Dual PLS Lasso ic=4 lambda1=0.0024 mu=0.0097 nu=2.2830541997830074e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0050 mu=0.0077 nu=3.886936166851257e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0038 mu=0.0028 nu=1.0819857226224784e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0022 mu=0.9657 nu=0.0020875482523305035 nbzeros=415
# Dual PLS Lasso ic=2 lambda1=0.0045 mu=0.1159 nu=0.0005270869181584169 nbzeros=244
# Dual PLS Lasso ic=3 lambda1=0.0122 mu=0.0189 nu=0.0002303729488796239 nbzeros=47
# Dual PLS Lasso ic=4 lambda1=0.0028 mu=0.0100 nu=2.7518699744292877e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.
-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0050 mu=0.0027 nu=1.3450246917869408e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0027 mu=0.9555 nu=0.002593203398948397 nbzeros=519
# Dual PLS Lasso ic=2 lambda1=0.0055 mu=0.1142 nu=0.000629771540189895 nbzeros=358
# Dual PLS Lasso ic=3 lambda1=0.0132 mu=0.0184 nu=0.00024272425652109458 nbzeros=136
# Dual PLS Lasso ic=4 lambda1=0.0037 mu=0.0096 nu=3.521601042574801e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0067 mu=0.0078 nu=5.173311261313805e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0051 mu=0.0024 nu=1.23223646319058e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0027 mu=1.0292 nu=0.0027523922905453345 nbzeros=519
# Dual PLS Lasso ic=2 lambda1=0.0060 mu=0.1149 nu=0.0006850532977339421 nbzeros=352
# Dual PLS Lasso ic=3 lambda1=0.0126 mu=0.0202 nu=0.00025371065696520927 nbzeros=200
# Dual PLS Lasso ic=4 lambda1=0.0034 mu=0.0098 nu=3.297561315015165e-05 nbzeros=0
# Dual PLS Lasso ic=5 lambda1=0.0050 mu=0.0074 nu=3.699363122281146e-05 nbzeros=0
# Dual PLS Lasso ic=6 lambda1=0.0055 mu=0.0029 nu=1.5977594390461546e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0025 mu=1.0223 nu=0.0025378148430081206 nbzeros=519
# Dual PLS Lasso ic=2 lambda1=0.0070 mu=0.1078 nu=0.0007542856439835253 nbzeros=327
# Dual PLS Lasso ic=3 lambda1=0.0104 mu=0.0159 nu=0.00016563915448337163 nbzeros=210
# Dual PLS Lasso ic=4 lambda1=0.0036 mu=0.0070 nu=2.52437148112526e-05 nbzeros=1
# Dual PLS Lasso ic=5 lambda1=0.0057 mu=0.0080 nu=4.5397920932643654e-05 nbzeros=1
# Dual PLS Lasso ic=6 lambda1=0.0054 mu=0.0025 nu=1.3224184860410495e-05 nbzeros=0
# Dual PLS Lasso ic=1 lambda1=0.0023 mu=1.0566 nu=0.0024168553212538394 nbzeros=519
# Dual PLS Lasso ic=2 lambda1=0.0055 mu=0.1134 nu=0.0006179962880776063 nbzeros=351
# Dual PLS Lasso ic=3 lambda1=0.0110 mu=0.0171 nu=0.0001876029969748964 nbzeros=217
# Dual PLS Lasso ic=4 lambda1=0.0038 mu=0.0076 nu=2.8975922345662506e-05 nbzeros=1
# Dual PLS Lasso ic=5 lambda1=0.0061 mu=0.0089 nu=5.408725571077801e-05 nbzeros=1
# ...
# Dual PLS LS, ic=2 nu=808205470924.8003 nbzeros=2190
# Dual PLS LS, ic=3 nu=72746008576.0000 nbzeros=2107
# Dual PLS LS, ic=4 nu=8053063680.0000 nbzeros=1998
# Dual PLS LS, ic=5 nu=8573681664.0000 nbzeros=1913
# Dual PLS LS, ic=6 nu=6146333081.6000 nbzeros=1831
# Dual PLS LS, ic=1 nu=3694024196096.0015 nbzeros=2334
# Dual PLS LS, ic=2 nu=67068598681.6000 nbzeros=2176
# Dual PLS LS, ic=3 nu=60720100147.2001 nbzeros=2055
# Dual PLS LS, ic=4 nu=189515431936.0000 nbzeros=1938
# Dual PLS LS, ic=5 nu=67568559718.4000 nbzeros=1839
# Dual PLS LS, ic=6 nu=34086269747.2000 nbzeros=1766
# Dual PLS LS, ic=1 nu=1638511232942.0803 nbzeros=2360
# Dual PLS LS, ic=4 nu=255445864284.1610 nbzeros=2537
# Dual PLS LS, ic=5 nu=2451822346.2400 nbzeros=2526
# Dual PLS LS, ic=6 nu=22459659059.2000 nbzeros=2513
# Dual PLS LS, ic=1 nu=25946461149593.7930 nbzeros=2568
# Dual PLS LS, ic=2 nu=10468445913088.0078 nbzeros=2556
# Dual PLS LS, ic=3 nu=3602460190965.7910 nbzeros=2542
# Dual PLS LS, ic=4 nu=2377261042892.8066 nbzeros=2531
# Dual PLS LS, ic=5 nu=1709219145318.4001 nbzeros=2516
# Dual PLS LS, ic=6 nu=1423439906734.0803 nbzeros=2510
# Dual PLS LS, ic=1 nu=47682726920192.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=108.5658 nbzeros=2594
# Dual PLS LS, ic=3 nu=103.4305 nbzeros=2594
# Dual PLS LS, ic=4 nu=103.8964 nbzeros=2594
# Dual PLS LS, ic=5 nu=103.8255 nbzeros=2594
# Dual PLS LS, ic=6 nu=105.2070 nbzeros=2594
# Dual PLS LS, ic=1 nu=43082816946176.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=173.6794 nbzeros=2594
# Dual PLS LS, ic=3 nu=165.8338 nbzeros=2594
# Dual PLS LS, ic=4 nu=147.3768 nbzeros=2594
# Dual PLS LS, ic=5 nu=144.0761 nbzeros=2594
# Dual PLS LS, ic=6 nu=143.0778 nbzeros=2594
# Dual PLS LS, ic=1 nu=51427938402304.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=151.5548 nbzeros=2594
# Dual PLS LS, ic=3 nu=153.9655 nbzeros=2594
# Dual PLS LS, ic=4 nu=147.9254 nbzeros=2594
# Dual PLS LS, ic=5 nu=149.9354 nbzeros=2594
# Dual PLS LS, ic=6 nu=154.2954 nbzeros=2594
# Dual PLS LS, ic=1 nu=78838419685376.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=141.9108 nbzeros=2594
# Dual PLS LS, ic=3 nu=142.1577 nbzeros=2594
# Dual PLS LS, ic=4 nu=136.0395 nbzeros=2594
# Dual PLS LS, ic=5 nu=143.2235 nbzeros=2594
# Dual PLS LS, ic=6 nu=146.4468 nbzeros=2594
# Dual PLS LS, ic=1 nu=81943681040384.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=178.1047 nbzeros=2594
# Dual PLS LS, ic=3 nu=177.9856 nbzeros=2594
# Dual PLS LS, ic=4 nu=176.1366 nbzeros=2594
# Dual PLS LS, ic=5 nu=175.5877 nbzeros=2594
# Dual PLS LS, ic=6 nu=176.1886 nbzeros=2594

# %%
# Best models per norms

for k, v in best_models.items():
    print(f"{k:5s} | RMSE = {v['rmse']:.4f} | params = {v['params']}")
# Out:
# Lasso | RMSE = 2.3059 | params = {'ppnu': np.float64(0.9500000000000001)}
# Ridge | RMSE = 0.2524 | params = {'ppnu': np.float64(1.0), 'nu2': np.float64(0.001)}
# LS    | RMSE = 0.2524 | params = {'ppnu': np.float64(1.0)}
# GLA   | RMSE = 0.2524 | params = {'ppnu': np.float64(0.01)}
# GLB   | RMSE = 0.6976 | params = {'ppnu': np.float64(0.99)}
# GLC   | RMSE = 0.5770 | params = {'ppnu': np.float64(1.0), 'gamma': np.float64(0.87)}

# %%
# Train Dual-sPLS for different norms using best hyperparameters

""" Hyperparameters from params was obtained with grids :

ppnu_grid = np.linspace(0.01, 1, 100)
nu2_grid = np.logspace(-3, 1, 7)          # For Ridge
gamma_grid = np.linspace(0.01, 1.0, 100)  # For GLC

results : 

Lasso | RMSE = 2.3059 | params = {'ppnu': np.float64(0.9500000000000001)}
Ridge | RMSE = 0.2524 | params = {'ppnu': np.float64(1.0), 'nu2': np.float64(0.001)}
LS    | RMSE = 0.2524 | params = {'ppnu': np.float64(1.0)}
GLA   | RMSE = 0.2524 | params = {'ppnu': np.float64(0.01)}
GLB   | RMSE = 0.6976 | params = {'ppnu': np.float64(0.99)}
GLC   | RMSE = 0.5770 | params = {'ppnu': np.float64(1.0), 'gamma': np.float64(0.87)}

Grids was dwarfed for computationnal time reasons"""

params = { # From grid search
    "Lasso": {"ppnu": 0.95},
    "Ridge": {"ppnu": 1.0, "nu2": 0.001},
    "LS":    {"ppnu": 1.0},
    "GLA":   {"ppnu": np.repeat(0.2, nG)}, # 0.01
    "GLB":   {"ppnu": np.repeat(0.99, nG)},
    "GLC":   {
                "ppnu": np.repeat(0.8, nG), # 1.0
                "gamma": np.repeat(1.0 / nG, nG)
    }
}

# ---------- Training ---------- #
models = {}

models["Lasso"] = dual_spls_lasso(
    X, y, n_components=n_comp, **params["Lasso"]
)

models["Ridge"] = d_spls_ridge(
    X, y, n_components=n_comp, **params["Ridge"]
)

models["LS"] = d_spls_ls(
    X, y, n_components=n_comp, **params["LS"]
)

models["GLA"] = dual_spls_gla_random(
    X, y, n_components=n_comp, indG=indG, **params["GLA"]
)

models["GLB"] = dual_spls_glb(
    X, y, n_components=n_comp, indG=indG, **params["GLB"]
)

models["GLC"] = dual_spls_glc(
    X, y, n_components=n_comp, indG=indG, **params["GLC"]
)
# Out:
# Dual PLS Lasso ic=1 lambda1=0.0290 mu=1.0117 nu=0.029366812756558044 nbzeros=2464
# Dual PLS Lasso ic=2 lambda1=0.2262 mu=0.0331 nu=0.007478281523767225 nbzeros=2370
# Dual PLS Lasso ic=3 lambda1=0.3190 mu=0.0074 nu=0.0023578097131475477 nbzeros=2311
# Dual PLS Lasso ic=4 lambda1=0.4544 mu=0.0023 nu=0.0010574967299771232 nbzeros=2294
# Dual PLS Lasso ic=5 lambda1=0.3143 mu=0.0012 nu=0.00037886834278565655 nbzeros=2243
# Dual PLS Lasso ic=6 lambda1=0.1413 mu=0.0007 nu=9.452395211529783e-05 nbzeros=2206
# Dual PLS Ridge ic=1 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS Ridge ic=2 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS Ridge ic=3 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS Ridge ic=4 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS Ridge ic=5 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS Ridge ic=6 lambda1=0.0000 mu=0.0000 nu2=0.001 nbzeros=2594
# Dual PLS LS, ic=1 nu=38487201939456.0000 nbzeros=2594
# Dual PLS LS, ic=2 nu=216.4823 nbzeros=2594
# Dual PLS LS, ic=3 nu=200.4194 nbzeros=2594
# Dual PLS LS, ic=4 nu=192.8157 nbzeros=2594
# Dual PLS LS, ic=5 nu=198.5535 nbzeros=2594
# Dual PLS LS, ic=6 nu=198.2664 nbzeros=2594
# Dual PLS GLA ic=1, nbzeros=2594, max|w|=0.0
# Dual PLS GLA ic=2, nbzeros=2594, max|w|=0.0
# Dual PLS GLA ic=3, nbzeros=2594, max|w|=0.0
# Dual PLS GLA ic=4, nbzeros=2594, max|w|=0.0
# Dual PLS GLA ic=5, nbzeros=2594, max|w|=0.0
# Dual PLS GLA ic=6, nbzeros=2594, max|w|=0.0
# Dual PLS GLB ic=1, nbzeros=13, max|w|=0.6513279965269541
# Dual PLS GLB ic=2, nbzeros=3, max|w|=0.9746336166945093
# Dual PLS GLB ic=3, nbzeros=6, max|w|=0.7192766848837753
# Dual PLS GLB ic=4, nbzeros=6, max|w|=0.594752583057566
# Dual PLS GLB ic=5, nbzeros=2, max|w|=0.5889396721873794
# Dual PLS GLB ic=6, nbzeros=4, max|w|=0.5254039215927466
# Dual PLS GLC ic=1, nbzeros=2, max|w|=0.54972537148152
# Dual PLS GLC ic=2, nbzeros=1, max|w|=0.4991276343073129
# Dual PLS GLC ic=3, nbzeros=3, max|w|=0.40156064130992064
# Dual PLS GLC ic=4, nbzeros=1, max|w|=0.5024153601654008
# Dual PLS GLC ic=5, nbzeros=1, max|w|=0.8351877880463091
# Dual PLS GLC ic=6, nbzeros=5, max|w|=0.33245446214640384

# %%
# RMSE from number of latent components for different norms

rmse_curves = {}

for name, model in models.items():
    rmse = []
    for k in range(n_comp):
        Bk = model["Bhat"][:, k]
        intercept = model["intercept"][k]
        y_pred = (X - model["Xmean"]) @ Bk + intercept
        rmse.append(np.sqrt(mean_squared_error(y, y_pred)))
    rmse_curves[name] = np.array(rmse)


plt.figure(figsize=(8,5))

for name, rmse in rmse_curves.items():
    plt.plot(
        range(1, n_comp+1),
        rmse,
        marker="o",
        label=name
    )

plt.xlabel("Latent component")
plt.ylabel("RMSE (validation)")
plt.title("RMSE for components values for different norms")
plt.legend()
plt.show()
plt.tight_layout()
plt.show()

for name, rmse in rmse_curves.items():
    print(name, rmse)
# Out:
# Lasso [1.12186797 2.56710427 2.56239559 2.07637978 2.11336892 2.37594834]
# Ridge [0.24663968 0.24663968 0.24663968 0.24663968 0.24663968 0.24663968]
# LS [0.24663968 0.24663968 0.24663968 0.24663968 0.24663968 0.24663968]
# GLA [0.24663968 0.24663968 0.24663968 0.24663968 0.24663968 0.24663968]
# GLB [0.16718195 0.51180223 0.77677182 0.79093535 0.58776173 0.71882341]
# GLC [0.51661463 0.42840631 0.41289588 1.24518058 2.0836337  2.50427622]

# %%
# Coefficients of the regression for all norms

best_components = {
    name: np.argmin(rmse) for name, rmse in rmse_curves.items()
}

plt.figure(figsize=(12,6))

for name, model in models.items():
    k_opt = best_components[name]
    beta = model["Bhat"][:, k_opt]

    plt.plot(
        beta,
        label=f"{name} (k={k_opt+1})",
        linewidth=1.5
    )

plt.axhline(0, color="black", linewidth=0.8)
plt.xlabel("Spectral variable index")
plt.ylabel("Regression coefficient")
plt.title("Dual-sPLS regression coefficients (optimal hyperparameters)")
plt.legend()
plt.tight_layout()
plt.show()
